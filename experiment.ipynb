# %%
import matplotlib.pyplot as plt

# %%
fig, axs = plt.subplots(1, 2, figsize=(20, 10))


X = list(range(5))
MLE_original = [45.0, 63.3, 68.3, 73.3, 77.5]
MLE_diffranker = [64.9, 77.2, 76.7, 76.9, 77.5]
MML_original = [43.3, 63.3,	67.5, 75.0, 78.3]
MML_diffranker = [59.5, 77.0, 74.9, 78.3, 78.3]

axs[0].plot(X, MLE_original, label='DeepRegex-MLE_original')
axs[0].plot(X, MLE_diffranker, label='DeepRegex-MLE_diffranker')
axs[0].plot(X, MML_original, label='DeepRegex-MML_original')
axs[0].plot(X, MML_diffranker, label='DeepRegex-MML_diffranker')
axs[0].legend(loc='lower right')
axs[0].set_title('Turk', fontsize=20)
axs[0].set_xlabel('Top-k', fontsize=14)
axs[0].set_ylabel('Accuracy', fontsize=14)
axs[0].set_xticks(X, ['1', '3', '5', '10', '20'])
axs[0].tick_params(axis='both', which='major', labelsize=14)


MLE_original = [35.8, 49.2, 58.3, 64.2,	64.2]
MLE_diffranker = [43.7, 55.2, 61.7, 64.2, 64.2]
MML_original = [29.2, 44.2, 48.3, 52.5, 54.2]
MML_diffranker = [35.1, 50.1, 51.3, 53.4, 54.2]

axs[1].plot(X, MLE_original, label='DeepRegex-MLE_original')
axs[1].plot(X, MLE_diffranker, label='DeepRegex-MLE_diffranker')
axs[1].plot(X, MML_original, label='DeepRegex-MML_original')
axs[1].plot(X, MML_diffranker, label='DeepRegex-MML_diffranker')
axs[1].legend(loc='lower right')
axs[1].set_title('KB13', fontsize=20)
axs[1].set_xlabel('Top-k', fontsize=14)
axs[1].set_ylabel('Accuracy', fontsize=14)
axs[1].set_xticks(X, ['1', '3', '5', '10', '20'])
axs[1].tick_params(axis='both', which='major', labelsize=14)
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(20, 20))


X = [1.0, 0.9, 0.8, 0.7, 0.6]
top_20 = [77.5, 77.5, 77.5, 77.5, 77.5]
original = [45.0, 45.0, 45.0, 45.0, 45.0]
diff = [73.3, 65.8, 62.5, 52.5, 40.8]
random = [71.7, 60.8, 52.5, 44.2, 26.7]

axs[0][0].plot(X, top_20, label='original top-20')
axs[0][0].plot(X, original, label='original top-1')
axs[0][0].plot(X, diff, label='diff string')
axs[0][0].plot(X, random, label='random string')
axs[0][0].legend()
axs[0][0].set_title('Turk DeepRegex-MLE', fontsize=20)
axs[0][0].set_xlabel('Oracle Prediction Accuracy', fontsize=14)
axs[0][0].set_ylabel('Top-20 or Top-1 Accuracy', fontsize=14)
axs[0][0].set_xticks(X, ['1.0', '0.9', '0.8', '0.7', '0.6'])
axs[0][0].tick_params(axis='both', which='major', labelsize=14)



top_20 = [78.3, 78.3, 78.3, 78.3, 78.3]
original = [43.3, 43.3, 43.3, 43.3, 43.3]
diff = [73.3, 67.5, 59.2, 55.8, 35.0]
random = [72.5, 58.3, 48.3, 45.8, 30.8]
axs[0][1].plot(X, top_20, label='original top-20')
axs[0][1].plot(X, original, label='original top-1')
axs[0][1].plot(X, diff, label='diff string')
axs[0][1].plot(X, random, label='random string')
axs[0][1].legend()
axs[0][1].set_title('Turk DeepRegex-MML', fontsize=20)
axs[0][1].set_xlabel('Oracle Prediction Accuracy', fontsize=14)
axs[0][1].set_ylabel('Top-20 or Top-1 Accuracy', fontsize=14)
axs[0][1].set_xticks(X, ['1.0', '0.9', '0.8', '0.7', '0.6'])
axs[0][1].tick_params(axis='both', which='major', labelsize=14)

top_20 = [64.2, 64.2, 64.2, 64.2, 64.2]
original = [35.8, 35.8, 35.8, 35.8, 35.8]
diff = [55.0, 50.0, 46.7, 36.7, 28.3]
random = [50.0, 43.3, 41.7, 27.5, 20.8]
axs[1][0].plot(X, top_20, label='original top-20')
axs[1][0].plot(X, original, label='original top-1')
axs[1][0].plot(X, diff, label='diff string')
axs[1][0].plot(X, random, label='random string')
axs[1][0].legend()
axs[1][0].set_title('KB13 DeepRegex-MLE', fontsize=20)
axs[1][0].set_xlabel('Oracle Prediction Accuracy', fontsize=14)
axs[1][0].set_ylabel('Top-20 or Top-1 Accuracy', fontsize=14)
axs[1][0].set_xticks(X, ['1.0', '0.9', '0.8', '0.7', '0.6'])
axs[1][0].tick_params(axis='both', which='major', labelsize=14)

top_20 = [54.2, 54.2, 54.2, 54.2, 54.2]
original = [29.2, 29.2, 29.2, 29.2, 29.2]
diff = [47.5, 42.5, 38.8, 33.3, 18.3]
random = [49.2, 42.5, 35.0, 35.8, 20.8]
axs[1][1].plot(X, top_20, label='original top-20')
axs[1][1].plot(X, original, label='original top-1')
axs[1][1].plot(X, diff, label='diff string')
axs[1][1].plot(X, random, label='random string')
axs[1][1].legend()
axs[1][1].set_title('KB13 DeepRegex-MML', fontsize=20)
axs[1][1].set_xlabel('Oracle Prediction Accuracy', fontsize=14)
axs[1][1].set_ylabel('Top-20 or Top-1 Accuracy', fontsize=14)
axs[1][1].set_xticks(X, ['1.0', '0.9', '0.8', '0.7', '0.6'])
axs[1][1].tick_params(axis='both', which='major', labelsize=14)
